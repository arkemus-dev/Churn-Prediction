# %%
import pandas as pd
import xgboost as xgb
import catboost as cb
import sklearn
import imblearn

print("✅ Setup Completed! Ready for project #2!")
# Out:
# ✅ Setup Completed! Ready for project #2!
